# %%
import os
import json
import pandas as pd

with open('C:/Users/visha/OneDrive/Desktop/assignment/Mortgage Pooling/Mortgage Pooling/Pool Optimization Data for TC v5/Pool Option Data/000e52ae-fe47-4ac6-82d5-dc293483d669.json', 'r') as f:
    data = json.load(f)
    df = pd.DataFrame({'count': data})
    df21 = pd.DataFrame([data])
    df21 = df21.drop(df21.index[0])
    df21

# %%
# List all files in a directory using os.listdir
basepath = 'C:/Users/visha/OneDrive/Desktop/assignment/Mortgage Pooling/Mortgage Pooling/Pool Optimization Data for TC v5/Pool Option Data/'
for entry in os.listdir(basepath):
    if os.path.isfile(os.path.join(basepath, entry)):
        with open(os.path.join(basepath, entry), 'r') as f:
            print(os.path.join(basepath, entry))
            data = json.load(f)
            df = pd.DataFrame({'count': data})
            df = pd.DataFrame([data])
            df21 = df21.append(df)
# Out:
# C:/Users/visha/OneDrive/Desktop/assignment/Mortgage Pooling/Mortgage Pooling/Pool Optimization Data for TC v5/Pool Option Data/000e52ae-fe47-4ac6-82d5-dc293483d669.json
# C:/Users/visha/OneDrive/Desktop/assignment/Mortgage Pooling/Mortgage Pooling/Pool Optimization Data for TC v5/Pool Option Data/00140e44-3acf-4cc6-98c3-9780948455b8.json
# C:/Users/visha/OneDrive/Desktop/assignment/Mortgage Pooling/Mortgage Pooling/Pool Optimization Data for TC v5/Pool Option Data/003ae2b2-9f6c-4b04-b92a-f3c22a2e9755.json
# C:/Users/visha/OneDrive/Desktop/assignment/Mortgage Pooling/Mortgage Pooling/Pool Optimization Data for TC v5/Pool Option Data/004481e9-b8f7-464a-a4e7-e649a214cfcf.json
# C:/Users/visha/OneDrive/Desktop/assignment/Mortgage Pooling/Mortgage Pooling/Pool Optimization Data for TC v5/Pool Option Data/00545d96-806e-439f-81aa-5bc5df52855f.json
# ...

# %%
# Out:
#          Agency Pool Balance Type Pool Option, j      Pool Type     Servicer
# 0    Fannie Mae  Standard Balance       pool_248   Multi-Issuer     Retained
# 0   Freddie Mac  Standard Balance       pool_106  Single-Issuer     Retained
# 0    Fannie Mae  Standard Balance       pool_383  Single-Issuer     Retained
# 0   Freddie Mac  Standard Balance       pool_167  Single-Issuer      Pingora
# 0    Fannie Mae  Standard Balance       pool_289  Single-Issuer      Pingora
# 0    Fannie Mae  Standard Balance       pool_405  Single-Issuer     Retained
# 0    Fannie Mae      High Balance       pool_264   Multi-Issuer  Two Harbors
# 0   Freddie Mac  Standard Balance        pool_53  Single-Issuer      Pingora
# 0   Freddie Mac  Standard Balance       pool_134  Single-Issuer      Pingora
# 0    Fannie Mae  Standard Balance       pool_434  Single-Issuer     Retained
# 0    Fannie Mae      High Balance       pool_269   Multi-Issuer      Pingora
# ...

# %%
df21.to_csv(r'C:/Users/visha/OneDrive/Desktop/assignment/Mortgage Pooling/Mortgage Pooling/CSVs/Pool Option Data/Pool Option Data.csv', index = False)
